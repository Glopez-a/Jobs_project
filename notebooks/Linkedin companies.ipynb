# %%
import pandas as pd

# %%
from linkedin_api import Linkedin

# Authenticate using any Linkedin account credentials
api = Linkedin('lopezandresgonzalo@gmail.com', '26chapacom')

# GET a profile
#profile = api.get_profile('billy-g')

# GET a profiles contact info
#contact_info = api.get_profile_contact_info('billy-g')

# GET 1st degree connections of a given profile
#connections = api.get_profile_connections('1234asc12304')

# %%
api

# %%
api.get_company("altostratus-solucions")
# Out:
# {'staffingCompany': False,
#  'companyIndustries': [{'localizedName': 'Information Technology & Services',
#    'entityUrn': 'urn:li:fs_industry:96'}],
#  'callToAction': {'callToActionType': 'LEARN_MORE',
#   'visible': True,
#   'callToActionMessage': {'textDirection': 'USER_LOCALE',
#    'text': 'Learn more'},
#   'url': 'https://www.altostratus.es/?utm_medium=social&utm_source=linkedin&utm_campaign=linkedin_descripcion_perfil'},
#  'staffCount': 108,
#  'adsRule': 'STANDARD',
#  'companyEmployeesSearchPageUrl': 'https://www.linkedin.com/vsearch/p?f_CC=5138458',
#  'viewerFollowingJobsUpdates': False,
#  'staffCountRange': {'start': 51, 'end': 200},
#  'permissions': {'landingPageAdmin': False,
#   'admin': False,
#   'adAccountHolder': False},
#  'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0/1639991060511?e=1696464000&v=beta&t=TatRachv47hKdlgLVEj4DbEtNQf5ouxtEltLJFwRhUw',
# ...

# %%
jobs = api.search_jobs(keywords=None, companies=["altostratus-solucions"], experience=None, job_type=None, job_title=['Data'], industries=None, location_name=None)

# %%
jobs
# Out:
# [{'dashEntityUrn': 'urn:li:fsd_jobPosting:3652204557',
#   'companyDetails': {'company': 'urn:li:fs_normalized_company:3035481',
#    '*companyResolutionResult': 'urn:li:fs_normalized_company:3035481',
#    '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebJobPostingWithCompanyName'],
#    '$type': 'com.linkedin.voyager.jobs.JobPostingCompany'},
#   'formattedLocation': 'Barcelona, Catalonia, Spain',
#   'listedAt': 1688383992000,
#   'title': 'DevOps Engineer',
#   '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebSearchJobJserpJobPostingLite'],
#   '$type': 'com.linkedin.voyager.jobs.JobPosting',
#   'entityUrn': 'urn:li:fs_normalized_jobPosting:3652204557',
#   'workRemoteAllowed': False},
#  {'dashEntityUrn': 'urn:li:fsd_jobPosting:3642937329',
#   'companyDetails': {'company': 'urn:li:fs_normalized_company:2734',
#    '*companyResolutionResult': 'urn:li:fs_normalized_company:2734',
#    '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebJobPostingWithCompanyName'],
# ...

# %%
len(jobs)
# Out:
# 1000

# %%
jobs[0]
# Out:
# {'dashEntityUrn': 'urn:li:fsd_jobPosting:3652204557',
#  'companyDetails': {'company': 'urn:li:fs_normalized_company:3035481',
#   '*companyResolutionResult': 'urn:li:fs_normalized_company:3035481',
#   '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebJobPostingWithCompanyName'],
#   '$type': 'com.linkedin.voyager.jobs.JobPostingCompany'},
#  'formattedLocation': 'Barcelona, Catalonia, Spain',
#  'listedAt': 1688383992000,
#  'title': 'DevOps Engineer',
#  '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebSearchJobJserpJobPostingLite'],
#  '$type': 'com.linkedin.voyager.jobs.JobPosting',
#  'entityUrn': 'urn:li:fs_normalized_jobPosting:3652204557',
#  'workRemoteAllowed': False}

# %%
api.get_job(3636728749)
# Out:
# {'dashEntityUrn': 'urn:li:fsd_jobPosting:3636728749',
#  'companyDetails': {'com.linkedin.voyager.deco.jobs.web.shared.WebCompactJobPostingCompany': {'companyResolutionResult': {'entityUrn': 'urn:li:fs_normalized_company:1441',
#     'name': 'Google',
#     'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#          'fileIdentifyingUrlPathSegment': '200_200/0/1519856215226?e=1696464000&v=beta&t=6tAbJIj47pIog2iyiNXfOAnO3AtGDSwf2kO0pr3I2SQ',
#          'expiresAt': 1696464000000,
#          'height': 200},
#         {'width': 100,
#          'fileIdentifyingUrlPathSegment': '100_100/0/1519856215226?e=1696464000&v=beta&t=cRKBP6nZzfeIIbwcI6aSPZ1Jl_a-4Zi3vEwJDYrhkfQ',
#          'expiresAt': 1696464000000,
#          'height': 100},
#         {'width': 400,
#          'fileIdentifyingUrlPathSegment': '400_400/0/1519856215226?e=1696464000&v=beta&t=grPFzld1XYPHFui5c4PR61hHJQsYWavfu686Khge3mE',
#          'expiresAt': 1696464000000,
# ...

# %%
companies = api.get_company("Altostratus Cloud Consulting")

# %%
companies
# Out:
# {'staffingCompany': False,
#  'companyIndustries': [{'localizedName': 'Information Technology & Services',
#    'entityUrn': 'urn:li:fs_industry:96'}],
#  'callToAction': {'callToActionType': 'LEARN_MORE',
#   'visible': True,
#   'callToActionMessage': {'textDirection': 'USER_LOCALE',
#    'text': 'Learn more'},
#   'url': 'https://www.altostratus.es/?utm_medium=social&utm_source=linkedin&utm_campaign=linkedin_descripcion_perfil'},
#  'staffCount': 109,
#  'adsRule': 'STANDARD',
#  'companyEmployeesSearchPageUrl': 'https://www.linkedin.com/vsearch/p?f_CC=5138458',
#  'viewerFollowingJobsUpdates': False,
#  'staffCountRange': {'start': 51, 'end': 200},
#  'permissions': {'landingPageAdmin': False,
#   'admin': False,
#   'adAccountHolder': False},
#  'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0/1639991060511?e=1695859200&v=beta&t=G61I0nQ-FSrI5lbWLyi22gLLyHHZ0Glo4ebi5ERZgxA',
# ...

# %%
companies = api.get_company("mercadona")

# %%
companies
# Out:
# {'staffingCompany': False,
#  'companyIndustries': [{'localizedName': 'Retail',
#    'entityUrn': 'urn:li:fs_industry:27'}],
#  'callToAction': {'callToActionType': 'VIEW_WEBSITE',
#   'visible': True,
#   'callToActionMessage': {'textDirection': 'USER_LOCALE',
#    'text': 'Visit website'},
#   'url': 'http://www.mercadona.com'},
#  'staffCount': 21554,
#  'adsRule': 'STANDARD',
#  'companyEmployeesSearchPageUrl': 'https://www.linkedin.com/vsearch/p?f_CC=131856',
#  'viewerFollowingJobsUpdates': False,
#  'staffCountRange': {'start': 10001},
#  'permissions': {'landingPageAdmin': False,
#   'admin': False,
#   'adAccountHolder': False},
#  'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#       'fileIdentifyingUrlPathSegment': '200_200/0/1685349197155?e=1695859200&v=beta&t=sHjtoHyJBg3wfttVS_GfUTZOEsXuV3NzZkAYRjjku9s',
#       'expiresAt': 1695859200000,
#       'height': 200},
#      {'width': 100,
# ...

# %%
jobs = api.search_jobs(companies="altostratus-solucions")

# %%
jobs
# Out:
# [{'dashEntityUrn': 'urn:li:fsd_jobPosting:3606263371',
#   'companyDetails': {'company': 'urn:li:fs_normalized_company:11015026',
#    '*companyResolutionResult': 'urn:li:fs_normalized_company:11015026',
#    '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebJobPostingWithCompanyName'],
#    '$type': 'com.linkedin.voyager.jobs.JobPostingCompany'},
#   'formattedLocation': 'Barcelona, Catalonia, Spain',
#   'listedAt': 1686149059000,
#   'title': 'Analista Programador/a Java',
#   '$recipeTypes': ['com.linkedin.voyager.deco.jserp.WebSearchJobJserpJobPostingLite'],
#   '$type': 'com.linkedin.voyager.jobs.JobPosting',
#   'entityUrn': 'urn:li:fs_normalized_jobPosting:3606263371',
#   'workRemoteAllowed': False},
#  {'dashEntityUrn': 'urn:li:fsd_jobPosting:3609017852',
#   'companyDetails': {'company': 'urn:li:fs_normalized_company:8120',
#    '*companyResolutionResult': 'urn:li:fs_normalized_company:8120',
# ...

# %%
updates = api.get_company_updates(public_id="altostratus-solucions", urn_id=None, max_results=None, results=None)

# %%
updates
# Out:
# [{'urn': 'urn:li:activity:7072127992071692288',
#   'entityUrn': 'urn:li:fs_feedUpdate:(V2&COMPANY_FEED,urn:li:activity:7072127992071692288)',
#   'id': 'activity:7072127992071692288',
#   'permalink': 'https://www.linkedin.com/feed/update/urn:li:activity:7072127992071692288',
#   'tracking': {'requestId': '0eafe564-465f-4392-b29f-1d9f050b21f3',
#    'trackingId': 'R+EmsRYSddFXykUtxKUSyg=='},
#   'value': {'com.linkedin.voyager.feed.render.UpdateV2': {'actor': {'urn': 'urn:li:company:5138458',
#      'image': {'attributes': [{'miniCompany': {'objectUrn': 'urn:li:company:5138458',
#          'entityUrn': 'urn:li:fs_miniCompany:5138458',
#          'name': 'Altostratus Cloud Consulting',
#          'showcase': False,
#          'active': True,
#          'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#              'fileIdentifyingUrlPathSegment': '200_200/0/1639991060511?e=1694044800&v=beta&t=-OaxydUY4eMxvkJHdIA7ssAUBvECafqtPG4CJ6f14sQ',
# ...

# %%
api.get_job(3644758468)
# Out:
# {'dashEntityUrn': 'urn:li:fsd_jobPosting:3644758468',
#  'companyDetails': {'com.linkedin.voyager.deco.jobs.web.shared.WebCompactJobPostingCompany': {'companyResolutionResult': {'entityUrn': 'urn:li:fs_normalized_company:1586',
#     'name': 'Amazon',
#     'logo': {'image': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#          'fileIdentifyingUrlPathSegment': '200_200/0/1612205615891?e=1696464000&v=beta&t=Ne5UagJo97195QAn-iVbAtph4paW1mGC2iz1TjD3eik',
#          'expiresAt': 1696464000000,
#          'height': 200},
#         {'width': 100,
#          'fileIdentifyingUrlPathSegment': '100_100/0/1612205615891?e=1696464000&v=beta&t=eKqnHDFY-xoiuTdoVA9qK5hbf-DD9h5UVq2gWJt1IT4',
#          'expiresAt': 1696464000000,
#          'height': 100},
#         {'width': 400,
#          'fileIdentifyingUrlPathSegment': '400_400/0/1612205615891?e=1696464000&v=beta&t=kzaIgRiVSVQT4r6jhBaCjs8DlJ_Tene3EeqRl8o-Ndo',
#          'expiresAt': 1696464000000,
# ...
